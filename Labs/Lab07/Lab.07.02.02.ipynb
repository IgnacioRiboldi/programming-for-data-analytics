# %% [markdown]
# # Lab 7.02.02

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# load dataset
dataset = sns.load_dataset('tips')

sns.lmplot(x="size", y="tip", data=dataset)

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# load dataset
dataset = sns.load_dataset('tips')

sns.lmplot(x="size", y="tip", data=dataset, x_jitter=.05)

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# load dataset
dataset = sns.load_dataset('tips')

sns.lmplot(x='size', y='tip', data=dataset, x_estimator=np.mean)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 7
#       4 # load dataset
#       5 dataset = sns.load_dataset('tips')
# ----> 7 sns.lmplot(x='size', y='tip', data=dataset, x_estimator=np.mean)
#       9 plt.show()
#
# NameError: name 'np' is not defined
